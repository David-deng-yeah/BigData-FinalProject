# %%
from anomaly_detection import anomaly_detection_, plot_pca
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 导入数据

# %%
Block32 = pd.read_csv('../../RSP数据块/Block 32.csv')
Block42 = pd.read_csv('../../RSP数据块/Block 42.csv')
Block_list = [Block32, Block42]
BlockAD_list = []

# %%
Block32
# Out:
#         label         1         2         3         4         5         6  \
# 0         1.0  0.708794 -0.723713  1.466915  0.454904 -0.675541  1.015649
# 1         1.0  0.900771  0.069098  1.612289  2.089648  1.109618  0.889506
# 2         0.0  1.366712  1.114166 -1.385177  1.040457 -0.843880  1.425866
# 3         1.0  0.907542  1.112218  1.354833  0.723252  1.008751  1.181458
# 4         0.0  1.772260 -0.638004 -0.451898  1.417073  0.161868  1.024169
# ...       ...       ...       ...       ...       ...       ...       ...
# 153995    0.0  2.344347 -0.523075 -0.051288  0.227995  1.327202  1.570881
# 153996    1.0  1.960027  0.489852  0.551394  0.283329  0.683751  0.350031
# 153997    0.0  0.825371 -0.702286 -1.740289  0.814598 -0.402187  0.980655
# 153998    1.0  0.878444  0.582379  0.584686  1.156430  1.615556  0.953906
# 153999    0.0  1.277769 -0.102321  1.385350  0.231090 -1.217010  1.265554
#
#                7         8         9  ...        19        20        21  \
# ...

# %%
for i, block in enumerate(Block_list):
    print(i)
    block_AD, _ = anomaly_detection_(block)
    BlockAD_list.append(block_AD)
# Out:
# 0
# 1

# %%
BlockAD_list[0]
# Out:
#                1         2         3         4         5         6         7  \
# 0      -0.497705 -0.714714  1.457004 -0.906343 -0.672894  0.051296 -0.594055
# 1      -0.156812  0.069875  1.601258  1.805322  1.099171 -0.214426  0.114963
# 2       0.670560  1.104106 -1.373133  0.064955 -0.839998  0.915424 -0.781564
# 3      -0.144789  1.102178  1.345785 -0.461215  0.999044  0.400575 -0.094031
# 4       1.390692 -0.629894 -0.447038  0.689674  0.158373  0.069243 -0.395804
# ...          ...       ...       ...       ...       ...       ...       ...
# 153995  2.406547 -0.516157 -0.049512 -1.282733  1.315159  1.220899 -0.430962
# 153996  1.724111  0.486266  0.548530 -1.190946  0.676428 -1.350838 -0.391897
# 153997 -0.290700 -0.693509 -1.725511 -0.309693 -0.401546 -0.022419 -0.798167
# 153998 -0.196459  0.577833  0.581566  0.257328  1.601397 -0.078767  1.465613
# 153999  0.512625 -0.099766  1.376067 -1.277598 -1.210392  0.577723  0.586665
#
# ...

# %%
import os
path = '../../RSP_AD/'

BlockAD_list[0].to_csv(os.path.join(path, 'RSP32_AD.csv'), index=False)
BlockAD_list[1].to_csv(os.path.join(path, 'RSP42_AD.csv'), index=False)

# 等RSP有序了再搞
# for i, block in BlockAD_list:
#     block.to_csv(os.path.join(path, 'RSP_AD'))

# %%
test = pd.read_csv('../../RSP_AD/RSP32_AD.csv')
test
# Out:
#                1         2         3         4         5         6         7  \
# 0      -0.497705 -0.714714  1.457004 -0.906343 -0.672894  0.051296 -0.594055
# 1      -0.156812  0.069875  1.601258  1.805322  1.099171 -0.214426  0.114963
# 2       0.670560  1.104106 -1.373133  0.064955 -0.839998  0.915424 -0.781564
# 3      -0.144789  1.102178  1.345785 -0.461215  0.999044  0.400575 -0.094031
# 4       1.390692 -0.629894 -0.447038  0.689674  0.158373  0.069243 -0.395804
# ...          ...       ...       ...       ...       ...       ...       ...
# 153225  2.406547 -0.516157 -0.049512 -1.282733  1.315159  1.220899 -0.430962
# 153226  1.724111  0.486266  0.548530 -1.190946  0.676428 -1.350838 -0.391897
# 153227 -0.290700 -0.693509 -1.725511 -0.309693 -0.401546 -0.022419 -0.798167
# 153228 -0.196459  0.577833  0.581566  0.257328  1.601397 -0.078767  1.465613
# 153229  0.512625 -0.099766  1.376067 -1.277598 -1.210392  0.577723  0.586665
#
# ...
