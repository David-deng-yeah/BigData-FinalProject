# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from copy import deepcopy
import seaborn as sns
from sklearn.preprocessing import KBinsDiscretizer, StandardScaler
import warnings 
warnings.filterwarnings('ignore')

# %%
Block1_AD = pd.read_csv('../../RSP_AD/Block 1 AD 0.003.csv')
X_rsp1_AD = Block1_AD.drop('label',axis=1)
y_rsp1_AD = Block1_AD['label']
print('X_rsp1 shape: ',X_rsp1_AD.shape)
# Out:
# X_rsp1 shape:  (153538, 28)

# %%
fea = X_rsp1_AD.columns
df_rsp1_AD = pd.DataFrame(data=X_rsp1_AD.values, columns=fea)
df_rsp1_AD
# Out:
#                1         2         3         4         5         6         7  \
# 0       0.493210  0.866778 -0.830316  2.571520 -0.279262  0.809716  0.387154
# 1       0.655356  0.731396  0.241781  3.067170 -0.474623  2.183550  1.168446
# 2       0.593681  0.027217  1.743236  1.053611  0.763017  0.723880 -1.656680
# 3       1.616885 -1.265240 -0.433588  0.528759  1.540286  0.923767 -0.240651
# 4       1.080669  0.221037  1.049104  1.071846  1.363433  1.124387  0.970400
# ...          ...       ...       ...       ...       ...       ...       ...
# 153533  0.474726  0.165521  0.116383  0.695433 -1.397509  0.822999 -0.566437
# 153534  0.421287 -1.839881  1.600637  0.614082  0.782287  1.171198 -1.248705
# 153535  0.601734 -1.101613 -0.724893  2.187400 -1.345621  0.945203 -0.584261
# 153536  2.479407  0.518097 -1.247017  3.280799 -1.219985  3.846312 -0.255505
# 153537  1.666664 -0.341917 -1.386842  0.591734 -0.901756  0.894819  0.134646
#
#                8         9        10  ...        19        20        21  \
# 0       1.601197  0.000000  0.739431  ... -0.314435  1.122981  0.000000
# 1       0.791809  0.000000  1.202756  ...  0.449264 -1.371455  3.101961
# 2      -1.571044  0.000000  1.214465  ...  0.505896  0.130798  3.101961
# 3       1.256375  2.173076  0.649788  ... -1.889304  0.005943  0.000000
# 4       1.130532  2.173076  1.018182  ...  0.775731 -0.477488  0.000000
# ...          ...       ...       ...  ...       ...       ...       ...
# 153533  0.215259  2.173076  1.399543  ... -0.554288  0.889363  0.000000
# 153534 -0.756667  0.000000  2.352381  ... -1.194729  0.097503  0.000000
# 153535  0.840594  2.173076  0.355300  ... -0.477668 -0.298252  3.101961
# 153536  0.389887  2.173076  2.554204  ...  0.540042  0.669063  3.101961
# 153537  0.909891  1.086538  0.479818  ... -1.307160  1.678447  0.000000
#
#               22        23        24        25        26        27        28
# 0       0.597446  0.763127  0.987707  1.534347  0.829040  1.518393  1.263348
# 1       0.619959  0.563526  1.180472  0.719782  0.591422  0.671538  0.645881
# 2       0.833194  0.999375  0.981343  1.028082  0.869200  0.936227  0.969262
# 3       0.815824  1.041715  1.253270  1.269991  0.848547  0.940010  0.884574
# 4       1.198861  0.985718  0.978730  1.124434  1.690711  1.168876  1.109496
# ...          ...       ...       ...       ...       ...       ...       ...
# 153533  0.620862  1.074294  0.991715  0.505848  0.721781  0.666523  0.631574
# 153534  0.959779  0.847217  0.996943  0.569942  0.766080  0.684140  0.654423
# 153535  0.850123  0.876434  0.984347  0.669142  0.743454  0.866564  0.748560
# 153536  1.360442  1.282749  0.966670  3.944360  1.142286  2.441039  2.115929
# 153537  0.622843  0.852226  0.987137  1.153926  0.794300  0.935070  0.872564
#
# [153538 rows x 28 columns]

# %%
plt.style.use('seaborn')

fig, axes = plt.subplots(ncols=7, nrows=4,figsize=[50,30])
for i, ax in zip(range(0,28), axes.flat):
    ax.set_title('fea'+str(i))
    ax.set_xlabel('values')
    ax.set_ylabel('nums')
    sns.distplot(df_rsp1_AD.iloc[:,i],
        hist=True,kde=True, ax=ax,color='royalblue')
plt.show()
